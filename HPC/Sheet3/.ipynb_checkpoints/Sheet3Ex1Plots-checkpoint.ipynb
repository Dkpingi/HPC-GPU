# %%
import numpy as np
import matplotlib.pyplot as plt

Onenode = np.loadtxt("Ex1resonenode.txt",delimiter = " ")
Twonodes = np.loadtxt("Ex1restwonodes.txt",delimiter = " ")
Onenode *= 1e6
Twonodes *= 1e6
plt.title("Ping-Pong time per message for m messages")
plt.semilogy()
plt.semilogx()
plt.ylabel("time (us)")
plt.xlabel("message size (byte)")
plt.plot(Onenode[:,0],Onenode[:,1],label = "One Node (m = 1000000)")
plt.plot(Twonodes[:,0],Twonodes[:,1],label = "Two Nodes (m = 10000)")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

Onenodebl = np.loadtxt("Ex2resonenodebl.txt",delimiter = " ")
Twonodesbl = np.loadtxt("Ex2restwonodesbl.txt",delimiter = " ")
Onenodenonbl = np.loadtxt("Ex2resblonenode.txt",delimiter = " ")
Twonodesnonbl = np.loadtxt("Ex2resbltwonodes.txt",delimiter = " ")
Onenode *= 1e6
Twonodes *= 1e6
plt.title("Ping-Pong time per message for m messages")
plt.semilogy()
plt.semilogx()
plt.ylabel("time (us)")
plt.xlabel("message size (byte)")
plt.plot(Onenodebl[:,0],Onenodebl[:,1],label = "One Node(Bl) (m = 1000000)")
plt.plot(Twonodesbl[:,0],Twonodesbl[:,1],label = "Two Nodes(Bl) (m = 10000)")
plt.plot(Onenodenonbl[:,0],Onenodenonbl[:,1],label = "One Node (Nonbl) (m = 1000000)")
plt.plot(Twonodesnonbl[:,0],Twonodesnonbl[:,1],label = "Two Nodes(Nonbl) (m = 10000)")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-8d387dce3b52> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 Onenodebl = np.loadtxt("Ex2resonenodebl.txt",delimiter = " ")
#       5 Twonodesbl = np.loadtxt("Ex2restwonodesbl.txt",delimiter = " ")
#       6 Onenodenonbl = np.loadtxt("Ex2resblonenode.txt",delimiter = " ")
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#     924             fname = str(fname)
#     925         if _is_string_like(fname):
# --> 926             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     927             fencoding = getattr(fh, 'encoding', 'latin1')
#     928             fh = iter(fh)
#
# ...
